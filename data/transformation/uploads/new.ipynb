# %%
def list_files_recursively(sftp, remote_path):
    files = []
    for entry in sftp.listdir_attr(remote_path):
        remote_file_path = os.path.join(remote_path, entry.filename)
        if paramiko.SFTPAttributes.is_dir(entry):
            files.extend(list_files_recursively(sftp, remote_file_path))
        else:
            files.append(remote_file_path)
    return files

# %%
import paramiko
import zipfile
import os
from io import StringIO

import paramiko
from io import StringIO
import os

def getSftpCon(hostname, port, username,password = None, pkey = None):
    transport = paramiko.Transport(hostname, 22)

    if pkey:
        key = paramiko.RSAKey(file_obj=StringIO(pkey.strip()))
        transport.connect(username = username, pkey=key)
    else:
        transport.connect(username=username, password=password)
    sftp = paramiko.SFTPClient.from_transport(transport)
    return sftp

hostname="sftp-gw-test.gps.ihost.com",
port='22',
username="r2radmin_devqa"
remote_path = '/akshay_test/input/config_run/input/New_recon_utsav/test_input'


key_file = "-----BEGIN RSA PRIVATE KEY-----\\n-----END RSA PRIVATE KEY-----\n"
key_file = StringIO(key_file)
key = paramiko.RSAKey.from_private_key(key_file)

sftp = getSftpCon(hostname=hostname, port=22, username=username,pkey=key)

files = list_files_recursively(sftp, remote_path)
print(files)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 31
#      28 key_file = StringIO(key_file)
#      29 key = paramiko.RSAKey.from_private_key(key_file)
# ---> 31 sftp = getSftpCon(hostname=hostname, port=22, username=username,pkey=key)
#      33 files = list_files_recursively(sftp, remote_path)
#      34 print(files)
#
# Cell In[12], line 11, in getSftpCon(hostname, port, username, password, pkey)
#      10 def getSftpCon(hostname, port, username,password = None, pkey = None):
# ---> 11     transport = paramiko.Transport(hostname, 22)
#      13     if pkey:
#      14         key = paramiko.RSAKey(file_obj=StringIO(pkey.strip()))
#
# ...

# %%
import pyspark
from pyspark.sql import SparkSession

#     .set("spark.sql.warehouse.dir", "abfss://iceberg-storage@dbupocstorage.dfs.core.windows.net/")

conf = (
pyspark.SparkConf().setMaster("local")
    .setAppName('app_name')
    .set("spark.jars.packages", "com.crealytics:spark-excel_2.13:3.5.1_0.20.4,org.apache.hadoop:hadoop-azure:3.3.6,org.apache.hadoop:hadoop-common:3.3.6")
    .set("fs.azure.account.key.dbupocstorage.dfs.core.windows.net", "KNlxX5taC5LWrVDICOVQkjBtSstR/ZEUgY1+u9VuEzKS/w4OZiCCn57TVIXKuozoy4VLb0k2iMHO+AStxza6yA==")
    )

spark = SparkSession.builder.config(conf=conf).getOrCreate()
# Out:
# ...
# Ivy Default Cache set to: /Users/akshay/.ivy2/cache
# The jars for the packages stored in: /Users/akshay/.ivy2/jars
# com.crealytics#spark-excel_2.13 added as a dependency
# org.apache.hadoop#hadoop-azure added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-480793f9-9e02-45a2-a6a7-1355399c9ca6;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/usr/local/spark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found com.crealytics#spark-excel_2.13;3.5.1_0.20.4 in central
# 	found org.apache.poi#poi;5.2.5 in central
# 	found org.apache.commons#commons-collections4;4.4 in central
# 	found org.apache.commons#commons-math3;3.6.1 in central
# 	found com.zaxxer#SparseBitSet;1.3 in central
# 	found org.apache.poi#poi-ooxml;5.2.5 in central
# 	found org.apache.poi#poi-ooxml-lite;5.2.5 in central
# 	found com.github.virtuald#curvesapi;1.08 in central
# ...

# %%
path = "abfss://r2r-file-storage@dbupocstorage.dfs.core.windows.net/akshay/input_files/AR_OI_AGFA_AR OPEN ITEMS_1723013799464.xlsx"

####### read excel file into pyspark ##########
df = spark.read \
    .format("com.crealytics.spark.excel") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("sheetName", "Index") \
    .load(path)

df.show()
# Out:
# +----------------+--------------------+
# |         Context|     Associated File|
# +----------------+--------------------+
# |      Cover Page|          Cover Page|
# |         Summary|Summary_AR Reconc...|
# |         Summary|Summary_AR Reconc...|
# |         Summary|Summary_Manual Re...|
# |AI Summarization|         AI Insights|
# |AI Summarization|1_Observation|Acc...|
# |AI Summarization|2_Risk|Risk Trx|M...|
# |AI Summarization|3_Risk|Risk Trx|A...|
# |      Validation| Validation_TB vs GL|
# |            Risk|  Risk_OI GT_30 days|
# |         Explain|Explain_AGFA EXPL...|
# |           Match|Match_S1_AGFA EXP...|
# |           Match|Match_S2_AGFA EXP...|
# |           Match|Match_S1_DOCUMENT...|
# |           Match|Match_S2_DOCUMENT...|
# |           Match|Match_S1_DOCTYPE ...|
# |           Match|Match_S2_DOCTYPE ...|
# |        Rec Grid|Rec Grid_TB TAGET...|
# |        Rec Grid| Rec Grid_FBL3N GLOI|
# |     Manual Grid|     Manual Grid_MRI|
# ...
